# %% [markdown]
# <a href="https://colab.research.google.com/github/Frellaa/Bilingual-audiobook-from-plain-ebook-pdf/blob/main/ReginaFiam_BigDataProject_Bilingualaudiobook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Aim of this Project:
# I am an Erasmus student in Bologna, and I wanted to learn Italian in a fun way. I also enjoy reading but don't really have the time for the traditional method, so I prefer audiobooks that I can listen to at the gym, while swimming, or walking. Therefore, I decided to combine these interests and created a tool that generates a bilingual audiobook from plain PDF ebook inputs. I used English as the original language because I feel comfortable with it, although my mother tongue is Hungarian. I know that language learning for babies happens by connecting the meaning of the spoken language they hear. Thus, I segmented the original book by sentences (or by other punctuation if the sentences were too long) and created an ABAB structured book, where:
#
# - A: Original language
# - B: Translated Language
#
# I then joined these segments to make an audiobook with proper pronunciation. I used **George Orwell's - Animal Farm**as an example in this notebook. However, note that even with GPU usage, the text-to-speech (TTS) part of the notebook takes more than 2.5 hours. I will provide a YouTube link with the rendered file.

# %% [markdown]
# ## Part I. Bilingual book making procedure

# %%
# !pip install transformers torch PyMuPDF pydub
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Collecting PyMuPDF
#   Downloading pymupdf-1.25.1-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Downloading pymupdf-1.25.1-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 19.4 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, PyMuPDF
# Successfully installed PyMuPDF-1.25.1 pydub-0.25.1

# %% [markdown]
# ### Function: `extract_text_from_pdf`
#
# This function extracts text from a PDF file, performing the following steps:
#
# - **Opens the PDF**: Uses the `fitz` library to open the specified PDF file.
# - **Extracts Text**: Iterates through each page, getting the text content.
# - **Processes Text**: Splits the page text into lines, then filters out lines that:
#   - Start with 'https://' to remove URLs.
#   - Contain the word "CHAPTER" (case-insensitive) to possibly skip chapter headings.
# - **Concatenates**: Joins the filtered lines back into a single string.
#
# Finally, it returns this cleaned, concatenated text string.

# %%
import fitz
import re

def extract_text_from_pdf(pdf_path):
    document = fitz.open(pdf_path)
    text = ''
    for page in document:
        # Get the text from the page and split it into lines
        page_text = page.get_text()
        lines = page_text.split('\n')

        # Filter out lines that start with 'https://' or contain "CHAPTER"
        filtered_lines = [
            line for line in lines
            if not line.strip().startswith('https://')
            and not re.search(r'\bCHAPTER\b', line.upper())
        ]

        # Join the filtered lines back into text
        text += '\n'.join(filtered_lines)

    return text

# %%
#pdf_extracted=extract_text_from_pdf("/content/animalfarm_merged.pdf")

# %% [markdown]
# ### Function: `segment_sentences`
#
# This function segments a given text into smaller parts based on token count, ensuring that each segment does not exceed a specified number of tokens (`max_tokens`). **It is important for the further audio processing because there are limits of tokens that can be processed.**  Here's how it works:
#
# - **Tokenization**: Converts the input text into sentences using `sent_tokenize` from NLTK, and then into words with `word_tokenize`.
#
# - **Processing Each Sentence:**
#   - If a sentence exceeds `max_tokens`:
#     - It splits the sentence into smaller segments at punctuation points like commas, semicolons, or colons if found within the last 10 words of the segment.
#     - If no suitable punctuation is found for segmentation, it splits at exactly `max_tokens`.
#
#   - If a sentence is within the token limit, it adds the whole sentence to the result.
#
# - **Return**: The function returns a list of these segments.
#
# ### Notes:
# - Requires NLTK's 'punkt_tab' dataset for sentence tokenization, which is downloaded in the script.
# - The `max_tokens` parameter is set to 250 by default, but can be adjusted for different needs.

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

# Download necessary data for sentence tokenization
nltk.download('punkt_tab') # Download the 'punkt_tab' dataset explicitly

def segment_sentences(text, max_tokens=200):
    sentences = sent_tokenize(text)
    result = []

    for sentence in sentences:
        words = word_tokenize(sentence)

        if len(words) > max_tokens:
            # If the sentence exceeds max_tokens, split it at reasonable punctuation
            segments = []
            segment = []
            for word in words:
                segment.append(word)
                if len(segment) == max_tokens:
                    # Look for a good split point within the last few words
                    for i in range(min(10, len(segment)), 0, -1):
                        if segment[-i] in [',', ';', ':']:
                            segments.append(' '.join(segment[:-i]))
                            segment = segment[-i:]
                            break
                    else:
                        # If no punctuation found, just split at max_tokens
                        segments.append(' '.join(segment))
                        segment = []

            # Append any remaining words in the last segment
            if segment:
                segments.append(' '.join(segment))

            result.extend(segments)
        else:
            # Sentence fits within token limit, add it directly
            result.append(sentence)

    return result
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# Example usage
text="This is an extraordinarily long sentence that we've crafted to go beyond three hundred tokens, including a plethora of words that are quite mundane like the, and, but, or, because, however, therefore, while, which, who, whom, whose, where, when, why, how, if, then, so, yet, nor, not, only, just, maybe, perhaps, possibly, likely, certainly, indeed, surely, definitely, absolutely, positively, undeniably, and we continue with nouns like book, chair, table, lamp, house, car, tree, river, mountain, ocean, sky, cloud, sun, moon, stars, planet, galaxy, universe, atom, molecule, cell, organism, species, genre, type, kind, variety, class, category, group, team, band, orchestra, choir, ensemble, collection, set, array, list, inventory, catalog, directory, index, archive, record, document, paper, essay, story, novel, poem, drama, comedy, tragedy, history, science, math, physics, chemistry, biology, geology, geography, astronomy, economics, psychology, sociology, philosophy, linguistics, literature, art, music, dance, theater, cinema, television, radio, internet, software, hardware, computer, laptop, smartphone, tablet, device, gadget, tool, instrument, machine, engine, motor, wheel, gear, lever, pulley, screw, nail, hammer, saw, drill, axe, knife, fork, spoon, plate, bowl, cup, glass, bottle, jar, can, box, bag, sack, wallet, purse, key, lock, door, window, wall, floor, ceiling, roof, garden, yard, park, forest, jungle, desert, beach, island, lake, pond, stream, brook, creek, canal, bridge, road, street, avenue, boulevard, highway, path, trail, track, route, journey, trip, voyage, expedition, adventure, experience, memory, thought, idea, concept, theory, hypothesis, principle, law, rule, regulation, policy, strategy, tactic, method, technique, skill, talent, ability, capacity, potential, power, strength, energy, force, speed, acceleration, momentum, velocity, mass, weight, volume, area, length, width, height, depth, dimension, size, shape, form, structure, pattern, design, style, fashion, trend, tradition, custom, culture, heritage, legacy, history, past, present, future, moment, instant, second, minute, hour, day, week, month, year, decade, century, millennium, era, epoch, period, age, stage, phase, step, level, degree, grade, rank, position, status, condition, situation, circumstance, context, environment, setting, scene, scenario, case, example, instance, occurrence, event, happening, incident, accident, emergency, crisis, challenge, problem, issue, matter, concern, topic, subject, theme, motif, element, component, part, piece, segment, section, portion, fraction, percentage, ratio, proportion, balance, harmony, melody, rhythm, beat, tempo, pace, tone, pitch, note, chord, scale, key, signature, measure, bar, line, verse, chorus, refrain, bridge, hook, lyric, word, syllable, sound, noise, silence, quiet, peace, calm, tranquility, serenity, bliss, happiness, joy, delight, pleasure, satisfaction, fulfillment, achievement, success, victory, triumph, progress, improvement, growth, development, evolution, change, transformation, transition, shift, move, action, activity, operation, function, purpose, goal, objective, aim, target, focus, concentration, attention, awareness, consciousness, knowledge, understanding, wisdom, insight, intuition, instinct, feeling, emotion, mood, temperament, character, personality, identity, self, ego, soul, spirit, mind, heart, body, health, fitness, wellness, vitality, vigor, strength, endurance, resilience, flexibility, agility, dexterity, coordination, balance, control, discipline, determination, willpower, motivation, inspiration, creativity, imagination, innovation, invention, discovery, exploration, investigation, research, study, learning, education, teaching, training, practice, exercise, work, labor, effort, exertion, struggle, fight, battle, war, peace, negotiation, compromise, agreement, contract, deal, transaction, exchange, trade, commerce, business, industry, market, economy, finance, investment, capital, asset, resource, wealth, prosperity, abundance, plenty, excess, surplus, deficit, shortage, scarcity, poverty, need, necessity, demand, supply, production, consumption, use, utility, benefit, advantage, gain, profit, income, revenue, earnings, salary, wage, fee, cost, expense, price, value, worth, merit, quality, standard, norm, average, mean, median, mode, range, variation, deviation, anomaly, exception, rarity, uniqueness, individuality, diversity, variety, multiplicity, complexity, intricacy, detail, specificity, precision, accuracy, exactness, correctness, truth, fact, reality, actuality, existence, being, life, living, survival, sustainability, continuity, permanence, stability, security, safety, protection, defense, guard, shield, armor, weapon, tool, utility, function, performance, efficiency, effectiveness, productivity, output, result, consequence, effect, impact, influence, power, authority, control, command, order, directive, instruction, guideline, rule, law, legislation, regulation, code, standard, norm, convention, tradition, custom, practice, habit, routine, procedure, process, method, approach, technique, strategy, tactic, plan, scheme, design, blueprint, model, prototype, sample, specimen, example, illustration, demonstration, explanation, description, definition, interpretation, analysis, evaluation, assessment, judgment, opinion, view, perspective, outlook, vision, foresight, prediction, forecast, estimate, guess, speculation, assumption, belief, faith, trust, confidence, assurance, certainty, conviction, commitment, dedication, devotion, loyalty, allegiance, fidelity, honesty, integrity, sincerity, authenticity, genuineness, reality, truth."
segments = segment_sentences(text)
for i, segment in enumerate(segments):
    print(f"Segment {i+1}: {segment}")
# Out:
# Segment 1: This is an extraordinarily long sentence that we 've crafted to go beyond three hundred tokens , including a plethora of words that are quite mundane like the , and , but , or , because , however , therefore , while , which , who , whom , whose , where , when , why , how , if , then , so , yet , nor , not , only , just , maybe , perhaps , possibly , likely , certainly , indeed , surely , definitely , absolutely , positively , undeniably , and we continue with nouns like book , chair , table , lamp , house , car , tree , river , mountain , ocean , sky , cloud , sun , moon , stars , planet , galaxy , universe , atom , molecule , cell , organism , species , genre , type , kind , variety , class , category , group , team , band , orchestra , choir , ensemble , collection , set , array , list , inventory , catalog , directory , index , archive
# Segment 2: , record , document , paper , essay , story , novel , poem , drama , comedy , tragedy , history , science , math , physics , chemistry , biology , geology , geography , astronomy , economics , psychology , sociology , philosophy , linguistics , literature , art , music , dance , theater , cinema , television , radio , internet , software , hardware , computer , laptop , smartphone , tablet , device , gadget , tool , instrument , machine , engine , motor , wheel , gear , lever , pulley , screw , nail , hammer , saw , drill , axe , knife , fork , spoon , plate , bowl , cup , glass , bottle , jar , can , box , bag , sack , wallet , purse , key , lock , door , window , wall , floor , ceiling , roof , garden , yard , park , forest , jungle , desert , beach , island , lake , pond , stream , brook , creek , canal , bridge , road
# Segment 3: , street , avenue , boulevard , highway , path , trail , track , route , journey , trip , voyage , expedition , adventure , experience , memory , thought , idea , concept , theory , hypothesis , principle , law , rule , regulation , policy , strategy , tactic , method , technique , skill , talent , ability , capacity , potential , power , strength , energy , force , speed , acceleration , momentum , velocity , mass , weight , volume , area , length , width , height , depth , dimension , size , shape , form , structure , pattern , design , style , fashion , trend , tradition , custom , culture , heritage , legacy , history , past , present , future , moment , instant , second , minute , hour , day , week , month , year , decade , century , millennium , era , epoch , period , age , stage , phase , step , level , degree , grade , rank , position , status , condition
# Segment 4: , situation , circumstance , context , environment , setting , scene , scenario , case , example , instance , occurrence , event , happening , incident , accident , emergency , crisis , challenge , problem , issue , matter , concern , topic , subject , theme , motif , element , component , part , piece , segment , section , portion , fraction , percentage , ratio , proportion , balance , harmony , melody , rhythm , beat , tempo , pace , tone , pitch , note , chord , scale , key , signature , measure , bar , line , verse , chorus , refrain , bridge , hook , lyric , word , syllable , sound , noise , silence , quiet , peace , calm , tranquility , serenity , bliss , happiness , joy , delight , pleasure , satisfaction , fulfillment , achievement , success , victory , triumph , progress , improvement , growth , development , evolution , change , transformation , transition , shift , move , action , activity , operation , function
# Segment 5: , purpose , goal , objective , aim , target , focus , concentration , attention , awareness , consciousness , knowledge , understanding , wisdom , insight , intuition , instinct , feeling , emotion , mood , temperament , character , personality , identity , self , ego , soul , spirit , mind , heart , body , health , fitness , wellness , vitality , vigor , strength , endurance , resilience , flexibility , agility , dexterity , coordination , balance , control , discipline , determination , willpower , motivation , inspiration , creativity , imagination , innovation , invention , discovery , exploration , investigation , research , study , learning , education , teaching , training , practice , exercise , work , labor , effort , exertion , struggle , fight , battle , war , peace , negotiation , compromise , agreement , contract , deal , transaction , exchange , trade , commerce , business , industry , market , economy , finance , investment , capital , asset , resource , wealth , prosperity , abundance , plenty
# Segment 6: , excess , surplus , deficit , shortage , scarcity , poverty , need , necessity , demand , supply , production , consumption , use , utility , benefit , advantage , gain , profit , income , revenue , earnings , salary , wage , fee , cost , expense , price , value , worth , merit , quality , standard , norm , average , mean , median , mode , range , variation , deviation , anomaly , exception , rarity , uniqueness , individuality , diversity , variety , multiplicity , complexity , intricacy , detail , specificity , precision , accuracy , exactness , correctness , truth , fact , reality , actuality , existence , being , life , living , survival , sustainability , continuity , permanence , stability , security , safety , protection , defense , guard , shield , armor , weapon , tool , utility , function , performance , efficiency , effectiveness , productivity , output , result , consequence , effect , impact , influence , power , authority , control , command , order
# Segment 7: , directive , instruction , guideline , rule , law , legislation , regulation , code , standard , norm , convention , tradition , custom , practice , habit , routine , procedure , process , method , approach , technique , strategy , tactic , plan , scheme , design , blueprint , model , prototype , sample , specimen , example , illustration , demonstration , explanation , description , definition , interpretation , analysis , evaluation , assessment , judgment , opinion , view , perspective , outlook , vision , foresight , prediction , forecast , estimate , guess , speculation , assumption , belief , faith , trust , confidence , assurance , certainty , conviction , commitment , dedication , devotion , loyalty , allegiance , fidelity , honesty , integrity , sincerity , authenticity , genuineness , reality , truth .

# %%
#segmented_text=segment_sentences(pdf_extracted)

# %% [markdown]
# ### Translation Using Transformers
#
# This code uses the Hugging Face `transformers` library to set up and perform English to Italian translation:
#
# - **Model Setup**: The `setup_translation_model` function initializes the tokenizer and model for the specified translation model, moving it to GPU if available for faster processing. (Note: I have a Colab Premium so I runned my code there, if you do not have it might take longer time.)
#
# - **Translation**: The `translate_sentence` function converts an English sentence into Italian by encoding the input, generating translated tokens, and decoding them back into text. It limits the output length to prevent excessive translation and  to manage computational resources.

# %%
#translation using transformers
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

def setup_translation_model(model_name="Helsinki-NLP/opus-mt-en-it"):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    return tokenizer, model, device

def translate_sentence(sentence, tokenizer, model, device):
    inputs = tokenizer(sentence, return_tensors="pt").to(device)
    outputs = model.generate(inputs["input_ids"], max_length = min(len(tokenizer.encode(sentence)) * 2, 512))  # Assuming doubling the length of the input as a safe upper bound, but not exceeding 512 tokens, num_beams=4, early_stopping=True)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %% [markdown]
# Loading the model

# %%
tokenizer, model, device = setup_translation_model()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/803k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.60M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# pytorch_model.bin:   0%|          | 0.00/307M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]

# %%
#translated_sentences = [translate_sentence(sent, tokenizer, model, device) for sent in segmented_text]

# %%
#the merged texts will not be explicitely used but it is handy to have a merged text if someone needs it.
def merge_sentences(original, translated):
    return [sent for pair in zip(original, translated) for sent in pair]

# %%
#Writing out the merged book

#merged_translated_sentences = merge_sentences(segmented_text, translated_sentences)
#with open('merged_translated_sentences.txt', 'w') as file:
#    for line in merged_translated_sentences:
#       file.write(f"{line}\n")

# %% [markdown]
# Defining a very simple text processing function to get rid of the '\n' and '\t' characters because later they would make some troubles during the TTS.

# %%
def preprocess_for_tts(text):
    # Replace newlines with spaces for TTS
    text = text.replace('\n', ' ')
    # Remove tabs
    text = text.replace('\t', ' ')
    # Optionally, you might want to add pauses where newlines were for better readability
    # text = text.replace('\n', ' <pause> ')  # If your TTS system supports custom tags for pauses
    return text

# %% [markdown]
# So after all function defined this can be run for real usage.

# %%
#text extraction ffrom pdf
pdf_extracted=extract_text_from_pdf("/content/animalfarm_merged.pdf")

#the segmentation of the extracted text
segmented_text=segment_sentences(pdf_extracted)

#translation of the segmented text to the desired language - here italian
translated_sentences = [translate_sentence(sent, tokenizer, model, device) for sent in segmented_text]

#process the texts to be suitable for further TTS applications
processed_original = [preprocess_for_tts(sentence) for sentence in segmented_text]
processed_translated = [preprocess_for_tts(sentence) for sentence in translated_sentences]

#write out the processed files and later read it again so if the runtime stops i dont need to rerun just open the file.
with open('processed_original.txt', 'w', encoding='utf-8') as file: # Added encoding='utf-8'
    for line in processed_original:
        file.write(f"{line}\n")

with open('processed_translated.txt', 'w', encoding='utf-8') as file: # Added encoding='utf-8'
    for line in processed_translated:
        file.write(f"{line}\n")

# %% [markdown]
# ## Part II. Text to speech to create the bilingual audiobook

# %%
# !pip install datasets
# !pip install --upgrade tensorflow  # Upgrade to the latest stable release
# !pip install --upgrade transformers  # Update transformers to potentially fix compatibility issues.
# !pip install --upgrade datasets
# !pip install --upgrade TTS
# !pip install numpy==1.23
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !pip install pydub
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.17.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Collecting numpy<2.1.0,>=1.26.0 (from tensorflow)
#   Using cached numpy-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Using cached numpy-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.0
#     Uninstalling numpy-1.23.0:
#       Successfully uninstalled numpy-1.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tts 0.22.0 requires numpy==1.22.0; python_version <= "3.10", but you have numpy 2.0.2 which is incompatible.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# cupy-cuda12x 12.2.0 requires numpy<1.27,>=1.20, but you have numpy 2.0.2 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.0.2 which is incompatible.
# gruut 2.2.3 requires numpy<2.0.0,>=1.19.0, but you have numpy 2.0.2 which is incompatible.
# langchain 0.3.12 requires numpy<2,>=1.22.4; python_version < "3.12", but you have numpy 2.0.2 which is incompatible.
# matplotlib 3.8.0 requires numpy<2,>=1.21, but you have numpy 2.0.2 which is incompatible.
# mizani 0.13.1 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# nx-cugraph-cu12 24.10.0 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# plotnine 0.14.4 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# pytensor 2.26.4 requires numpy<2,>=1.17.0, but you have numpy 2.0.2 which is incompatible.
# scikit-image 0.25.0 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# scipy 1.11.4 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.0.2 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.18.0 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.0.2 which is incompatible.
# xarray 2024.11.0 requires pandas>=2.1, but you have pandas 1.5.3 which is incompatible.
# Successfully installed numpy-2.0.2
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.17.0)
# Requirement already satisfied: TTS in /usr/local/lib/python3.10/dist-packages (0.22.0)
# Requirement already satisfied: cython>=0.29.30 in /usr/local/lib/python3.10/dist-packages (from TTS) (3.0.11)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from TTS) (1.11.4)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.10/dist-packages (from TTS) (2.5.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from TTS) (2.5.1+cu121)
# Requirement already satisfied: soundfile>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (0.12.1)
# Requirement already satisfied: librosa>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (0.10.0)
# Requirement already satisfied: scikit-learn>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (1.6.0)
# Requirement already satisfied: inflect>=5.6.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (7.4.0)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from TTS) (4.67.1)
# Requirement already satisfied: anyascii>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (0.3.2)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (6.0.2)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (2024.9.0)
# Requirement already satisfied: aiohttp>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from TTS) (3.11.10)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from TTS) (24.2)
# Requirement already satisfied: flask>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from TTS) (3.1.0)
# Requirement already satisfied: pysbd>=0.3.4 in /usr/local/lib/python3.10/dist-packages (from TTS) (0.3.4)
# Requirement already satisfied: umap-learn>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from TTS) (0.5.7)
# Requirement already satisfied: pandas<2.0,>=1.4 in /usr/local/lib/python3.10/dist-packages (from TTS) (1.5.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (3.8.0)
# Requirement already satisfied: trainer>=0.0.32 in /usr/local/lib/python3.10/dist-packages (from TTS) (0.0.36)
# Requirement already satisfied: coqpit>=0.0.16 in /usr/local/lib/python3.10/dist-packages (from TTS) (0.0.17)
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from TTS) (0.42.1)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.10/dist-packages (from TTS) (0.53.0)
# Requirement already satisfied: hangul-romanize in /usr/local/lib/python3.10/dist-packages (from TTS) (0.1.0)
# Requirement already satisfied: gruut==2.2.3 in /usr/local/lib/python3.10/dist-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.2.3)
# Requirement already satisfied: jamo in /usr/local/lib/python3.10/dist-packages (from TTS) (0.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from TTS) (3.9.1)
# Requirement already satisfied: g2pkk>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from TTS) (0.1.2)
# Requirement already satisfied: bangla in /usr/local/lib/python3.10/dist-packages (from TTS) (0.0.2)
# Requirement already satisfied: bnnumerizer in /usr/local/lib/python3.10/dist-packages (from TTS) (0.0.2)
# Requirement already satisfied: bnunicodenormalizer in /usr/local/lib/python3.10/dist-packages (from TTS) (0.1.7)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (0.8.0)
# Requirement already satisfied: transformers>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (4.47.1)
# Requirement already satisfied: encodec>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from TTS) (0.1.1)
# Requirement already satisfied: unidecode>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from TTS) (1.3.8)
# Requirement already satisfied: num2words in /usr/local/lib/python3.10/dist-packages (from TTS) (0.5.14)
# Requirement already satisfied: spacy>=3 in /usr/local/lib/python3.10/dist-packages (from spacy[ja]>=3->TTS) (3.7.5)
# Collecting numpy==1.22.0 (from TTS)
#   Using cached numpy-1.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: numba>=0.57.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (0.60.0)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (2.16.0)
# Requirement already satisfied: dateparser~=1.1.0 in /usr/local/lib/python3.10/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (1.1.8)
# Requirement already satisfied: gruut-ipa<1.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (0.13.0)
# Requirement already satisfied: gruut-lang-en~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (2.0.1)
# Requirement already satisfied: jsonlines~=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (1.2.0)
# Requirement already satisfied: networkx<3.0.0,>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (2.8.8)
# Requirement already satisfied: python-crfsuite~=0.9.7 in /usr/local/lib/python3.10/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (0.9.11)
# Requirement already satisfied: gruut-lang-es~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.0.1)
# Requirement already satisfied: gruut-lang-fr~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.0.2)
# Requirement already satisfied: gruut-lang-de~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.1->TTS) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.1->TTS) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.1->TTS) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.1->TTS) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.1->TTS) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.1->TTS) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.1->TTS) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.1->TTS) (1.18.3)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.10/dist-packages (from flask>=2.0.1->TTS) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from flask>=2.0.1->TTS) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.10/dist-packages (from flask>=2.0.1->TTS) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from flask>=2.0.1->TTS) (8.1.7)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.10/dist-packages (from flask>=2.0.1->TTS) (1.9.0)
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.10/dist-packages (from inflect>=5.6.0->TTS) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from inflect>=5.6.0->TTS) (4.4.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->TTS) (3.0.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->TTS) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->TTS) (4.4.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->TTS) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->TTS) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->TTS) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->TTS) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->TTS) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->TTS) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->TTS) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->TTS) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->TTS) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->TTS) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->TTS) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->TTS) (2.8.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from num2words->TTS) (0.6.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.57.0->TTS) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0,>=1.4->TTS) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->TTS) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.0->TTS) (1.17.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (0.15.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.10.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3->spacy[ja]>=3->TTS) (3.5.0)
# Requirement already satisfied: sudachipy!=0.6.1,>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from spacy[ja]>=3->TTS) (0.6.9)
# Requirement already satisfied: sudachidict-core>=20211220 in /usr/local/lib/python3.10/dist-packages (from spacy[ja]>=3->TTS) (20241021)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.1->TTS) (3.16.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1->TTS) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.1->TTS) (1.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from trainer>=0.0.32->TTS) (5.9.5)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from trainer>=0.0.32->TTS) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.0->TTS) (0.27.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.0->TTS) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.0->TTS) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.0->TTS) (0.4.5)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.1->TTS) (0.5.13)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.0->TTS) (2.22)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser~=1.1.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1.2->flask>=2.0.1->TTS) (3.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jsonlines~=1.2.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (1.17.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3->spacy[ja]>=3->TTS) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa>=0.10.0->TTS) (4.3.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=3->spacy[ja]>=3->TTS) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=3->spacy[ja]>=3->TTS) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS) (7.1.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->trainer>=0.0.32->TTS) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->trainer>=0.0.32->TTS) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->trainer>=0.0.32->TTS) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->trainer>=0.0.32->TTS) (4.25.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->trainer>=0.0.32->TTS) (0.7.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3->spacy[ja]>=3->TTS) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS) (0.1.2)
# Using cached numpy-1.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albucore 0.0.19 requires numpy>=1.24.4, but you have numpy 1.22.0 which is incompatible.
# albumentations 1.4.20 requires numpy>=1.24.4, but you have numpy 1.22.0 which is incompatible.
# arviz 0.20.0 requires numpy>=1.23.0, but you have numpy 1.22.0 which is incompatible.
# astropy 6.1.7 requires numpy>=1.23, but you have numpy 1.22.0 which is incompatible.
# bigframes 1.29.0 requires numpy>=1.24.0, but you have numpy 1.22.0 which is incompatible.
# chex 0.1.88 requires numpy>=1.24.1, but you have numpy 1.22.0 which is incompatible.
# cudf-cu12 24.10.1 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.0 which is incompatible.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# ibis-framework 9.2.0 requires numpy<3,>=1.23.2, but you have numpy 1.22.0 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.22.0 which is incompatible.
# jaxlib 0.4.33 requires numpy>=1.24, but you have numpy 1.22.0 which is incompatible.
# langchain 0.3.12 requires numpy<2,>=1.22.4; python_version < "3.12", but you have numpy 1.22.0 which is incompatible.
# mizani 0.13.1 requires numpy>=1.23.5, but you have numpy 1.22.0 which is incompatible.
# mizani 0.13.1 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# numexpr 2.10.2 requires numpy>=1.23.0, but you have numpy 1.22.0 which is incompatible.
# nx-cugraph-cu12 24.10.0 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# nx-cugraph-cu12 24.10.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.0 which is incompatible.
# pandas-stubs 2.2.2.240909 requires numpy>=1.23.5, but you have numpy 1.22.0 which is incompatible.
# plotnine 0.14.4 requires numpy>=1.23.5, but you have numpy 1.22.0 which is incompatible.
# plotnine 0.14.4 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# pylibraft-cu12 24.10.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.0 which is incompatible.
# pymc 5.19.1 requires numpy>=1.25.0, but you have numpy 1.22.0 which is incompatible.
# rmm-cu12 24.10.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.0 which is incompatible.
# scikit-image 0.25.0 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# scikit-image 0.25.0 requires numpy>=1.24, but you have numpy 1.22.0 which is incompatible.
# statsmodels 0.14.4 requires numpy<3,>=1.22.3, but you have numpy 1.22.0 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.22.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.18.0 which is incompatible.
# xarray 2024.11.0 requires numpy>=1.24, but you have numpy 1.22.0 which is incompatible.
# xarray 2024.11.0 requires pandas>=2.1, but you have pandas 1.5.3 which is incompatible.
# xarray-einstats 0.8.0 requires numpy>=1.23, but you have numpy 1.22.0 which is incompatible.
# Successfully installed numpy-1.22.0
# Collecting numpy==1.23
#   Using cached numpy-1.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Using cached numpy-1.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.0
#     Uninstalling numpy-1.22.0:
#       Successfully uninstalled numpy-1.22.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tts 0.22.0 requires numpy==1.22.0; python_version <= "3.10", but you have numpy 1.23.0 which is incompatible.
# albucore 0.0.19 requires numpy>=1.24.4, but you have numpy 1.23.0 which is incompatible.
# albumentations 1.4.20 requires numpy>=1.24.4, but you have numpy 1.23.0 which is incompatible.
# bigframes 1.29.0 requires numpy>=1.24.0, but you have numpy 1.23.0 which is incompatible.
# chex 0.1.88 requires numpy>=1.24.1, but you have numpy 1.23.0 which is incompatible.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# ibis-framework 9.2.0 requires numpy<3,>=1.23.2, but you have numpy 1.23.0 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# jaxlib 0.4.33 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# mizani 0.13.1 requires numpy>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# mizani 0.13.1 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# nx-cugraph-cu12 24.10.0 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# pandas-stubs 2.2.2.240909 requires numpy>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# plotnine 0.14.4 requires numpy>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# plotnine 0.14.4 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# pymc 5.19.1 requires numpy>=1.25.0, but you have numpy 1.23.0 which is incompatible.
# scikit-image 0.25.0 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# scikit-image 0.25.0 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.23.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.18.0 which is incompatible.
# xarray 2024.11.0 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# xarray 2024.11.0 requires pandas>=2.1, but you have pandas 1.5.3 which is incompatible.
# Successfully installed numpy-1.23.0
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)

# %%
#now read those processed files for further analysis
with open('processed_original.txt', 'r', encoding='utf-8') as file:
    processed_original = [line.strip() for line in file]

with open('processed_translated.txt', 'r', encoding='utf-8') as file:
    processed_translated = [line.strip() for line in file]

# %% [markdown]
# it is necessary to remove the marks at the end of the sentences, because otherwise the trasnlated version should pronounce it which i wanted to avoid.

# %%
import re

def clean_text(text):
    return re.sub(r'[.,!?]', '', text)

processed_original = [clean_text(line) for line in processed_original]
processed_translated = [clean_text(line) for line in processed_translated]

# %% [markdown]
# It is not recommended to run the codes above on CPU, because:
# - significantly longer running time (~10x)
# - due to the longer running time, the runtime in colab disconnects because of inactivity and this results truncated audio files.

# %%
#import torch

# Check if CUDA is available
#device = "cuda" if torch.cuda.is_available() else "cpu"

# Initialize TTS with the appropriate device
#tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2", gpu=(device == "cuda"))

# %% [markdown]
# TTS on GPU:

# %%
#!pip install numpy==1.23
from TTS.api import TTS

# Initialize TTS with XTTS model for Italian
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2", gpu=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/TTS/api.py:70: UserWarning: `gpu` will be deprecated. Please use `tts.to(device)` instead.
#   warnings.warn("`gpu` will be deprecated. Please use `tts.to(device)` instead.")
#  > You must confirm the following:
#  | > "I have purchased a commercial license from Coqui: licensing@coqui.ai"
#  | > "Otherwise, I agree to the terms of the non-commercial CPML: https://coqui.ai/cpml" - [y/n]
#  | | > y
#  > Downloading model to /root/.local/share/tts/tts_models--multilingual--multi-dataset--xtts_v2
# 100%|█████████▉| 1.87G/1.87G [00:44<00:00, 42.9MiB/s]
# 100%|██████████| 1.87G/1.87G [00:44<00:00, 42.1MiB/s]
# 100%|██████████| 4.37k/4.37k [00:00<00:00, 18.3kiB/s]
#  77%|███████▋  | 280k/361k [00:00<00:00, 2.19MiB/s]
# 100%|██████████| 361k/361k [00:00<00:00, 1.00MiB/s]
# 100%|██████████| 32.0/32.0 [00:00<00:00, 111iB/s]
#  50%|████▉     | 3.87M/7.75M [00:00<00:00, 38.7MiB/s]
#  > Model's license - CPML
#  > Check https://coqui.ai/cpml.txt for more info.
#  > Using model: xtts
# 100%|██████████| 7.75M/7.75M [00:14<00:00, 38.7MiB/s]/usr/local/lib/python3.10/dist-packages/TTS/tts/layers/xtts/xtts_manager.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.speakers = torch.load(speaker_file_path)
# /usr/local/lib/python3.10/dist-packages/TTS/utils/io.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location, **kwargs)
# GPT2InferenceModel has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.

# %%
# Path to an audio file of the speaker you want to clone (must be at least 3 seconds long). Experience: the longer and clearer the voice is, the better the results's quality will be.
speaker_wav = "/content/voice_training_1984-by-george-orwell-lex-fridman.mp3"

# %%
# Find the index and value of the longest element- just for checking the succes of tokenization
longest_element_index, longest_element = max(enumerate(processed_translated), key=lambda x: len(x[1]))

print(f"The longest element '{longest_element}' is at index {longest_element_index}.")
# Out:
# The longest element 'Под руководством нашего лидера товарища Наполеона я положил пять яиц за шесть дней; или две коровы наслаждающиеся напитком в бассейне возгласят:  спасибо товарищу Наполеону за то как прекрасно вкусна эта вода  Общее чувство на ферме было хорошо выражено в стихотворении озаглавленном "Комрад Наполеон" которое было составлено Минимусом и которое шло следующим образом: "Дружок без отца"' is at index 977.

# %% [markdown]
# **Experience**: it is recommended to add you drive to the Colab to save the result file there, because the runtime is long and therefore I usually leave it to run during the night and then the colab's runtime break due to inactivity and the result file is also lost if not saved to the computer/drive.

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#define a path in your drive where you wanna receive the audiobook
drive_output_path = "/content/drive/MyDrive/big_data"

# %%
import os
from pydub import AudioSegment

# Assuming processed_original and processed_translated lists are already defined and populated.

# Create a list to store the concatenated audio segments
concatenated_audio = []

for i in range(min(len(processed_original), len(processed_translated))):  # Iterate up to the length of the shorter list
    original_file = f"original_{i}.wav"
    translated_file = f"translated_{i}.wav"

    tts.tts_to_file(text=processed_original[i], file_path=original_file, language="en", speaker_wav=speaker_wav)
    tts.tts_to_file(text=processed_translated[i], file_path=translated_file, language="it", speaker_wav=speaker_wav)

    # Load audio files using pydub
    original_audio = AudioSegment.from_wav(original_file)
    translated_audio = AudioSegment.from_wav(translated_file)

    # Concatenate audio segments
    concatenated_audio.append(original_audio)
    concatenated_audio.append(translated_audio)

    # Remove temporary files
    os.remove(original_file)
    os.remove(translated_file)


# Combine all audio segments into a single file
final_audio = sum(concatenated_audio)
final_audio.export("final_output.wav", format="wav")

# Export the combined audio to your Google Drive
final_audio.export(os.path.join(drive_output_path, "final_audio_merged_en_ru.wav"), format="wav")
# Out:
#  > Text splitted to sentences.
# ['M r Jones of the Manor Farm had locked the hen-houses for the night but was too drunk to remember to shut the pop- holes']
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
#  > Processing time: 7.649575233459473
#  > Real-time factor: 0.8511966789351099
#  > Text splitted to sentences.
# ['Мистер Джонс из поместья запер курятники на ночь но был слишком пьян чтобы заткнуть дыры']
#  > Processing time: 3.9614100456237793
#  > Real-time factor: 0.3732867158376254
#  > Text splitted to sentences.
# ['With the ring of light from his lantern dancing from side to side he lurched across the yard kicked off his boots at the back door drew himself a last glass of beer from the barrel in the scullery and made his way up to bed where Mrs Jones was already snoring']
# [!] Warning: The text length exceeds the character limit of 250 for language 'en', this might cause truncated audio.
#  > Processing time: 8.972793340682983
#  > Real-time factor: 0.45406788905477685
#  > Text splitted to sentences.
# ['С кольцом света от фонаря танцующего из стороны в сторону он прыгнул через двор снял ботинки у задней двери нарисовал себе последний бокал пива из ствола в скуллерии и пошёл в постель где миссис Джонс уже храпела']
#  > Processing time: 8.540159702301025
#  > Real-time factor: 0.3754795849332781
#  > Text splitted to sentences.
# ['As soon as the light in the bedroom went out there was a stirring and a fluttering all through the farm buildings']
#  > Processing time: 2.7913942337036133
#  > Real-time factor: 0.46053994712352353
#  > Text splitted to sentences.
# ['Как только свет в спальне вышел всколыхнули все здания фермы']
#  > Processing time: 3.148526191711426
#  > Real-time factor: 0.5769262941034847
#  > Text splitted to sentences.
# ['Word had gone round during the day that old Major the prize Middle White boar had had a strange dream on the previous night and wished to communicate it to the other animals']
#  > Processing time: 4.739825248718262
#  > Real-time factor: 0.3829554828451577
#  > Text splitted to sentences.
# ['Ходили слухи в течение дня что старый майор приз Мидл Белый кабан видел странный сон прошлой ночью и хотел сообщить об этом другим животным']
#  > Processing time: 5.894772291183472
#  > Real-time factor: 0.38116328361972607
#  > Text splitted to sentences.
# ['It had been agreed that they should all meet in the big barn as soon as Mr Jones was safely out of the way']
#  > Processing time: 4.119462490081787
#  > Real-time factor: 0.5295340214666507
#  > Text splitted to sentences.
# ['Было решено что они все должны встретиться в большом амбаре как только мистер Джонс будет в безопасности']
#  > Processing time: 3.8207316398620605
#  > Real-time factor: 0.3839747532403487
#  > Text splitted to sentences.
# ['Old Major (so he was always called though the name under which he had been exhibited was Willingdon Beauty) was so highly regarded on the farm that everyone was quite ready to lose an hour’s sleep in order to hear what he had to say']
#  > Processing time: 6.269257545471191
#  > Real-time factor: 0.39156222772954846
#  > Text splitted to sentences.
# ['Старый майор (так что его всегда звали хотя имя под которым он был выставлен было Виллингдон Красотка) был настолько высоко оценен на ферме что все были готовы потерять час сна чтобы услышать то что он должен был сказать']
# [!] Warning: The text length exceeds the character limit of 213 for language 'it', this might cause truncated audio.
#  > Processing time: 8.697018146514893
#  > Real-time factor: 0.42177492814744116
#  > Text splitted to sentences.
# ['At one end of the big barn on a sort of raised platform Major was already ensconced on his bed of straw under a lantern which hung from a beam']
#  > Processing time: 3.654985189437866
#  > Real-time factor: 0.37475087152697417
#  > Text splitted to sentences.
# ['В одном конце большого амбара на какой-то поднятой платформе майор уже был скован на своей соломинке под фонарем который висел на луче']
#  > Processing time: 6.92042350769043
#  > Real-time factor: 0.48419600175335703
#  > Text splitted to sentences.
# ['He was twelve years old and had lately grown rather stout but he was still a majestic-looking pig with a wise and benevolent appearance in spite of the fact that his tushes had never been cut']
#  > Processing time: 5.2121803760528564
#  > Real-time factor: 0.3863301285832218
#  > Text splitted to sentences.
# ['Ему было двенадцать лет и он в последнее время довольно сильно вырос но он все еще был величественной свиньей с мудрым и добрым внешностью несмотря на то что его раны никогда не были порезаны']
#  > Processing time: 9.352377891540527
#  > Real-time factor: 0.43145133671808283
#  > Text splitted to sentences.
# ['Before long the other animals began to arrive and make themselves comfortable after their different fashions']
#  > Processing time: 2.6183786392211914
#  > Real-time factor: 0.3815642447051607
#  > Text splitted to sentences.
# ['Вскоре другие животные начали приходить и чувствовать себя комфортно после того как они разошлись в моде']
#  > Processing time: 3.7500905990600586
#  > Real-time factor: 0.384502165525604
#  > Text splitted to sentences.
# ['First came the three dogs Bluebell Jessie and Pincher and then the pigs who settled down in the straw immediately in front of the platform']
#  > Processing time: 5.33810830116272
#  > Real-time factor: 0.5183245615824613
#  > Text splitted to sentences.
# ['Сначала пришли три собаки Блубелл Джесси и Пинчер а затем свиньи которые поселились в соломинке прямо перед платформой']
#  > Processing time: 4.370864391326904
#  > Real-time factor: 0.38452585313101756
#  > Text splitted to sentences.
# ['The hens perched themselves on the window-sills the pigeons fluttered up to the rafters the sheep and cows lay down behind the pigs and began to chew the cud']
#  > Processing time: 4.182145833969116
#  > Real-time factor: 0.3815637025778675
#  > Text splitted to sentences.
# ['Куры наткнулись на витрины голуби взмахнули до плотников овцы и коровы лежали за свиньями и начали жевать кубок']
#  > Processing time: 5.346783876419067
#  > Real-time factor: 0.48782102149553314
#  > Text splitted to sentences.
# ['The two cart-horses Boxer and Clover came in together walking very slowly and setting down their vast hairy hoofs with great care lest there should be some small animal concealed in the straw']
#  > Processing time: 5.43258810043335
#  > Real-time factor: 0.3773391197978786
#  > Text splitted to sentences.
# ['Две лошади Боксер и Кловер пришли вместе очень медленно двигаясь и спуская свои огромные волосатые копыта с большой осторожностью чтобы не было какого-то маленького животного спрятанного в соломинке']
#  > Processing time: 8.094037532806396
#  > Real-time factor: 0.4316626862311372
#  > Text splitted to sentences.
# ['Clover was a stout motherly mare approaching middle life who had never quite got her figure back after her fourth foal']
#  > Processing time: 3.3754162788391113
#  > Real-time factor: 0.3860690147958462
#  > Text splitted to sentences.
# ['Кловер была крутой материнской кобылой приближающейся к средней жизни которая так и не получила свою фигуру после четвертого жеребца']
#  > Processing time: 5.482127666473389
#  > Real-time factor: 0.3795557493272363
#  > Text splitted to sentences.
# ['Boxer was an enormous beast nearly eighteen hands high and as strong as any two ordinary horses put together']
#  > Processing time: 3.6273977756500244
#  > Real-time factor: 0.46010193829431106
#  > Text splitted to sentences.
# ['Боксёр был огромным зверем почти 18 рук высотой и таким же сильным как и все две обычные лошади собравшиеся вместе']
#  > Processing time: 4.679002046585083
#  > Real-time factor: 0.425093921514277
#  > Text splitted to sentences.
# ['A white stripe down his nose gave him a somewhat stupid appearance and in fact he was not of first-rate intelligence but he was universally respected for his steadiness of character and tremendous powers of work']
#  > Processing time: 5.044835090637207
#  > Real-time factor: 0.3781568321612402
#  > Text splitted to sentences.
# ['Белая полоса в его носу дала ему несколько глупый вид и на самом деле он не был первоклассным интеллектом но его повсеместно уважали за его твердость характера и огромные возможности работы']
#  > Processing time: 7.563594341278076
#  > Real-time factor: 0.4663167562105242
#  > Text splitted to sentences.
# ['After the horses came Muriel the white goat and Benjamin the donkey']
#  > Processing time: 2.1767032146453857
#  > Real-time factor: 0.39885242889019706
#  > Text splitted to sentences.
# ['После того как пришли лошади Мюриэль белый козел и Бенджамин осел']
#  > Processing time: 3.316708564758301
#  > Real-time factor: 0.3793542195043185
#  > Text splitted to sentences.
# ['Benjamin was the oldest animal on the farm and the worst tempered']
#  > Processing time: 1.920954942703247
#  > Real-time factor: 0.40056226818170865
#  > Text splitted to sentences.
# ['Бенджамин был старейшим животным на ферме и самым кротким']
#  > Processing time: 2.872572898864746
#  > Real-time factor: 0.4624184705347481
#  > Text splitted to sentences.
# ['He seldom talked and when he did it was usually to make some cynical remark — for instance he would say that God had given him a tail to keep the flies off but that he would sooner have had no tail and no flies']
#  > Processing time: 5.634113311767578
#  > Real-time factor: 0.4513988958653389
#  > Text splitted to sentences.
# ['Он редко разговаривал и когда он это делал он обычно делал некоторые циничные замечания — например он говорил что Бог дал ему хвост чтобы удержать мух но что раньше у него не было хвоста и не было мух']
#  > Processing time: 9.800921440124512
#  > Real-time factor: 0.4033233258583891
#  > Text splitted to sentences.
# ['Alone among the animals on the farm he never laughed']
#  > Processing time: 1.4206173419952393
#  > Real-time factor: 0.4464739508408641
#  > Text splitted to sentences.
# ['Один среди животных на ферме он никогда не смеялся']
#  > Processing time: 1.6746408939361572
#  > Real-time factor: 0.38560810057740463
#  > Text splitted to sentences.
# ['If asked why he would say that he saw nothing to laugh at']
#  > Processing time: 1.8518307209014893
#  > Real-time factor: 0.38244480926755053
#  > Text splitted to sentences.
# ['Если бы спросили почему он бы сказал что нечего смеяться']
#  > Processing time: 1.7322032451629639
#  > Real-time factor: 0.3854662679218811
#  > Text splitted to sentences.
# ['Nevertheless without openly admitting it he was devoted to Boxer; the two of them usually spent their Sundays together in the small paddock beyond the orchard grazing side by side and never speaking']
#  > Processing time: 5.15879225730896
#  > Real-time factor: 0.4068826520691301
#  > Text splitted to sentences.
# ['Тем не менее не признавая это открыто он был предан Боксеру; они оба обычно проводили свои воскресенья вместе в маленьком засаде за садом высаживаясь бок о бок и никогда не разговаривая']
#  > Processing time: 9.47069263458252
#  > Real-time factor: 0.42977372607046777
#  > Text splitted to sentences.
# ['The two horses had just lain down when a brood of ducklings which had lost their mother filed into the barn cheeping feebly and wandering from side to side to find some place where they would not be trodden on']
#  > Processing time: 5.405364036560059
#  > Real-time factor: 0.4037762107910635
#  > Text splitted to sentences.
# ['Эти две лошади просто лежали когда утята потерявшие мать погрузились в амбар подглядывая и блуждая по бокам чтобы найти место где они не могли бы быть погружены']
#  > Processing time: 6.810384750366211
#  > Real-time factor: 0.4348186928004834
#  > Text splitted to sentences.
# ['Clover made a sort of wall round them with her great foreleg and the ducklings nestled down inside it and promptly fell asleep']
#  > Processing time: 3.4751503467559814
#  > Real-time factor: 0.37790511888448564
#  > Text splitted to sentences.
# ['Кловер сделала какую-то стену вокруг них с большой передней ножкой и утята погрузились в нее и быстро заснули']
#  > Processing time: 5.425638437271118
#  > Real-time factor: 0.4590341930974437
#  > Text splitted to sentences.
# ['At the last moment Mollie the foolish pretty white mare who drew Mr Jones’s trap came mincing daintily in chewing at a lump of sugar']
#  > Processing time: 5.425139904022217
#  > Real-time factor: 0.4228562259052439
#  > Text splitted to sentences.
# ['В последний момент Молли глупая красивая белая кобыла которая нарисовала ловушку мистера Джонсона пришёл в подобие пожевал кусок сахара']
#  > Processing time: 5.246952533721924
#  > Real-time factor: 0.3762791518205509
#  > Text splitted to sentences.
# ['She took a place near the front and began flirting her white mane hoping to draw attention to the red ribbons it was plaited with']
#  > Processing time: 4.927610874176025
#  > Real-time factor: 0.5052350075123753
#  > Text splitted to sentences.
# ['Она заняла место рядом с фронтом и начала флиртовать со своей белой гривой надеясь привлечь внимание к красным лентам с которыми она была покрыта']
#  > Processing time: 5.8716020584106445
#  > Real-time factor: 0.3834068508290533
#  > Text splitted to sentences.
# ['Last of all came the cat who looked round as usual for the warmest place and finally squeezed herself in between Boxer and Clover; there she purred contentedly throughout Major’s speech without listening to a word of what he was saying']
#  > Processing time: 5.912909030914307
#  > Real-time factor: 0.4022672537013763
#  > Text splitted to sentences.
# ['Последний из них пришел кот который как обычно оглядывался вокруг в самое теплое место и наконец сжался между Боксером и Кловером; там она довольна чистила всю речь майора не выслушав ни слова из того что он говорил']
# [!] Warning: The text length exceeds the character limit of 213 for language 'it', this might cause truncated audio.
#  > Processing time: 8.790288209915161
#  > Real-time factor: 0.4326315467050938
#  > Text splitted to sentences.
# ['All the animals were now present except Moses the tame raven who slept on a perch behind the back door']
#  > Processing time: 3.6250174045562744
#  > Real-time factor: 0.3859194368987343
#  > Text splitted to sentences.
# ['Все животные присутствовали сейчас кроме Моисея румянного ворона который спал за задней дверью']
#  > Processing time: 5.357558012008667
#  > Real-time factor: 0.5048468126700475
#  > Text splitted to sentences.
# ['When Major saw that they had all made themselves comfortable and were waiting attentively he cleared his throat and began: “Comrades you have heard already about the strange dream that I had last night']
#  > Processing time: 5.169989347457886
#  > Real-time factor: 0.37608295431329636
#  > Text splitted to sentences.
# ['Когда майор увидел что они все устроились и внимательно ждали он прочистил горло и начал: "Комрады вы уже слышали о странном сне который у меня был прошлой ночью']
#  > Processing time: 5.183886289596558
#  > Real-time factor: 0.3902782459901806
#  > Text splitted to sentences.
# ['But I will come to the dream later']
#  > Processing time: 1.1250784397125244
#  > Real-time factor: 0.5322687005591564
#  > Text splitted to sentences.
# ['Но я приду к сну позже']
#  > Processing time: 2.341391086578369
#  > Real-time factor: 0.5524275965058748
#  > Text splitted to sentences.
# ['I have something else to say first']
#  > Processing time: 1.0491092205047607
#  > Real-time factor: 0.4087655200758053
#  > Text splitted to sentences.
# ['Сначала мне нужно кое-что сказать']
#  > Processing time: 1.6259217262268066
#  > Real-time factor: 0.39331637334672953
#  > Text splitted to sentences.
# ['I do not think comrades that I shall be with you for many months longer and before I die I feel it my duty to pass on to you such wisdom as I have acquired']
#  > Processing time: 3.560053825378418
#  > Real-time factor: 0.38088651332191853
#  > Text splitted to sentences.
# ['Я не думаю товарищи что пробуду с вами еще много месяцев и прежде чем умереть я чувствую что мой долг передать вам такую мудрость какую я приобрел']
#  > Processing time: 6.287014961242676
#  > Real-time factor: 0.43528221519530585
#  > Text splitted to sentences.
# ['I have had a long life I have had much time for thought as I lay alone in my stall and I think I may say that I understand the nature of life on this earth as well as any animal now living']
#  > Processing time: 5.395518064498901
#  > Real-time factor: 0.3954948317981782
#  > Text splitted to sentences.
# ['У меня была долгая жизнь у меня было много времени для размышлений когда я лежала одна в своей кабинке и я думаю что могу сказать что я понимаю природу жизни на этой земле а также любое животное которое сейчас живет']
# [!] Warning: The text length exceeds the character limit of 213 for language 'it', this might cause truncated audio.
#  > Processing time: 10.170301675796509
#  > Real-time factor: 0.4355889920426722
#  > Text splitted to sentences.
# ['It is about this that I wish to speak to you']
#  > Processing time: 1.1761934757232666
#  > Real-time factor: 0.40191957196407807
#  > Text splitted to sentences.
# ['Именно об этом я и хочу поговорить с вами']
#  > Processing time: 1.656242847442627
#  > Real-time factor: 0.3907737843060897
#  > Text splitted to sentences.
# ['“Now comrades what is the nature of this life of ours']
#  > Processing time: 2.2082600593566895
#  > Real-time factor: 0.3803597543183274
#  > Text splitted to sentences.
# ['- Итак товарищи какова природа нашей жизни']
#  > Processing time: 1.626502275466919
#  > Real-time factor: 0.3979271167011979
#  > Text splitted to sentences.
# ['Let us face it: our lives are miserable laborious and short']
#  > Processing time: 1.8205459117889404
#  > Real-time factor: 0.3880804075304151
#  > Text splitted to sentences.
# ['Давайте посмотрим правде в глаза: наша жизнь несчастна трудолюбива и коротка']
#  > Processing time: 3.132085084915161
#  > Real-time factor: 0.462686757171048
#  > Text splitted to sentences.
# ['We are born we are given just so much food as will keep the breath in our bodies and those of us who are capable of it are forced to work to the last atom of our strength; and the very instant that our usefulness has come to an end we are slaughtered with hideous cruelty']
# [!] Warning: The text length exceeds the character limit of 250 for language 'en', this might cause truncated audio.
#  > Processing time: 7.783657550811768
#  > Real-time factor: 0.40853307926314764
#  > Text splitted to sentences.
# ['Мы рождаемся мы получаем столько еды сколько в наших телах и те из нас кто способен на это вынуждены работать до последнего атома нашей силы; и в тот самый момент когда наша полезность приходит к концу мы забиваемся отвратительной жестокостью']
# [!] Warning: The text length exceeds the character limit of 213 for language 'it', this might cause truncated audio.
#  > Processing time: 9.654808282852173
#  > Real-time factor: 0.44138439757192405
#  > Text splitted to sentences.
# ['No animal in England knows the meaning of happiness or leisure after he is a year old']
#  > Processing time: 2.309615135192871
#  > Real-time factor: 0.39466067677466526
#  > Text splitted to sentences.
# ['Ни одно животное в Англии не знает значения счастья или отдыха после того как ему исполнилось год']
#  > Processing time: 3.788969039916992
#  > Real-time factor: 0.3768256446659165
#  > Text splitted to sentences.
# ['No animal in England is free']
#  > Processing time: 1.116617202758789
#  > Real-time factor: 0.41090469494044224
#  > Text splitted to sentences.
# ['Ни одно животное в Англии не бесплатно']
#  > Processing time: 1.779453992843628
#  > Real-time factor: 0.4353470679722395
#  > Text splitted to sentences.
# ['The life of an animal is misery and slavery: that is the plain truth']
#  > Processing time: 2.865355968475342
#  > Real-time factor: 0.5621094226412926
#  > Text splitted to sentences.
# ['Жизнь животного - это несчастье и рабство: это очевидная истина']
#  > Processing time: 2.6461613178253174
#  > Real-time factor: 0.41285419066319656
#  > Text splitted to sentences.
# ['“But is this simply part of the order of nature']
#  > Processing time: 1.8358075618743896
#  > Real-time factor: 0.3952464140303302
#  > Text splitted to sentences.
# ['▪ Но является ли это просто частью порядка природы']
#  > Processing time: 2.3281705379486084
#  > Real-time factor: 0.3811940148046128
#  > Text splitted to sentences.
# ['Is it because this land of ours is so poor that it cannot afford a decent life to those who dwell upon it']
#  > Processing time: 2.515531063079834
#  > Real-time factor: 0.3889505493444291
#  > Text splitted to sentences.
# ['Это потому что наша земля настолько бедна что она не может позволить себе достойную жизнь тем кто живет на ней']
#  > Processing time: 4.486733675003052
#  > Real-time factor: 0.48790971718327
#  > Text splitted to sentences.
# ['No comrades a thousand times no']
#  > Processing time: 1.1985573768615723
#  > Real-time factor: 0.44872640178955564
#  > Text splitted to sentences.
# ['Нет товарищи тысячу раз нет']
#  > Processing time: 1.4853153228759766
#  > Real-time factor: 0.38760654787700344
#  > Text splitted to sentences.
# ['The soil of England is fertile its climate is good it is capable of affording food in abundance to an enormously greater number of animals than now inhabit it']
#  > Processing time: 4.294103622436523
#  > Real-time factor: 0.38807866448097145
#  > Text splitted to sentences.
# ['Почва Англии плодородна ее климат хорош она способна обеспечить пищу в изобилии для огромного числа животных чем сейчас']
#  > Processing time: 5.1482014656066895
#  > Real-time factor: 0.4094214983431946
#  > Text splitted to sentences.
# ['This single farm of ours would support a dozen horses twenty cows hundreds of sheep — and all of them living in a comfort and a dignity that are now almost beyond our imagining']
#  > Processing time: 5.55995512008667
#  > Real-time factor: 0.46855703234082074
#  > Text splitted to sentences.
# ['Наша единственная ферма будет содержать дюжину лошадей двадцать коров сотни овец — и все они будут жить в комфорте и достоинстве которые сейчас почти превосходят наши воображения']
#  > Processing time: 5.7912023067474365
#  > Real-time factor: 0.37701358963514153
#  > Text splitted to sentences.
# ['Why then do we continue in this miserable condition']
#  > Processing time: 1.4638381004333496
#  > Real-time factor: 0.38668811235570444
#  > Text splitted to sentences.
# ['Почему же тогда мы продолжаем жить в этом жалком состоянии']
#  > Processing time: 3.545492649078369
#  > Real-time factor: 0.5319686507361053
#  > Text splitted to sentences.
# ['Because nearly the whole of the produce of our labour is stolen from us by human beings']
#  > Processing time: 2.3923604488372803
#  > Real-time factor: 0.40478474445105916
#  > Text splitted to sentences.
# ['Потому что почти весь продукт нашего труда украден у нас людьми']
#  > Processing time: 2.5257744789123535
#  > Real-time factor: 0.38162843479345326
#  > Text splitted to sentences.
# ['There comrades is the answer to all our problems']
#  > Processing time: 1.238924503326416
#  > Real-time factor: 0.39660692941851733
#  > Text splitted to sentences.
# ['Вот товарищи ответ на все наши проблемы']
#  > Processing time: 1.3368690013885498
#  > Real-time factor: 0.40112619040683545
#  > Text splitted to sentences.
# ['It is summed up in a single word — Man']
#  > Processing time: 1.8568005561828613
#  > Real-time factor: 0.39580870324663664
#  > Text splitted to sentences.
# ['Она резюмируется одним словом — человеком']
#  > Processing time: 1.6773498058319092
#  > Real-time factor: 0.4377196934599697
#  > Text splitted to sentences.
# ['Man is the only real enemy we have']
#  > Processing time: 1.321103811264038
#  > Real-time factor: 0.5147430562336026
#  > Text splitted to sentences.
# ['Человек - наш единственный настоящий враг']
#  > Processing time: 2.929868221282959
#  > Real-time factor: 0.5426319906538877
#  > Text splitted to sentences.
# ['Remove Man from the scene and the root cause of hunger and overwork is abolished for ever']
#  > Processing time: 2.216693878173828
#  > Real-time factor: 0.3848911743553366
#  > Text splitted to sentences.
# ['Избавь человека от сцены и коренная причина голода и чрезмерной работы навсегда исчезнет']
#  > Processing time: 2.8941311836242676
#  > Real-time factor: 0.37938500308496087
#  > Text splitted to sentences.
# ['“Man is the only creature that consumes without producing']
#  > Processing time: 1.3660531044006348
#  > Real-time factor: 0.3921249603212091
#  > Text splitted to sentences.
# ['▪ Человек - единственное существо которое потребляет без производства']
#  > Processing time: 2.7774417400360107
#  > Real-time factor: 0.37908902624414453
#  > Text splitted to sentences.
# ['He does not give milk he does not lay eggs he is too weak to pull the plough he cannot run fast enough to catch rabbits']
#  > Processing time: 4.2363505363464355
#  > Real-time factor: 0.5373419772574718
#  > Text splitted to sentences.
# ['Он не дает молока он не откладывает яйца он слишком слаб чтобы тянуть плуг он не может бежать достаточно быстро чтобы поймать кроликов']
#  > Processing time: 4.433505535125732
#  > Real-time factor: 0.38146499441812765
#  > Text splitted to sentences.
# ['Yet he is lord of all the animals']
#  > Processing time: 1.6537559032440186
#  > Real-time factor: 0.3859580616694603
#  > Text splitted to sentences.
# ['И все же он - повелитель всех животных']
#  > Processing time: 2.267639398574829
#  > Real-time factor: 0.39373699712245636
#  > Text splitted to sentences.
# ['He sets them to work he gives back to them the bare minimum that will prevent them from starving and the rest he keeps for himself']
#  > Processing time: 4.686264753341675
#  > Real-time factor: 0.4856929091674059
#  > Text splitted to sentences.
# ['Он ставит их на работу возвращает им голый минимум который не даст им голодать а остальное оставляет для себя']
#  > Processing time: 5.501345157623291
#  > Real-time factor: 0.39584092807129945
#  > Text splitted to sentences.
# ['Our labour tills the soil our dung fertilises it and yet there is not one of us that owns more than his bare skin']
#  > Processing time: 3.4614529609680176
#  > Real-time factor: 0.3851687413673031
#  > Text splitted to sentences.
# ['Наш труд доходит до почвы наш навоз удобряет его и тем не менее нет ни одного из нас кто владеет больше чем его голая кожа']
#  > Processing time: 5.534543991088867
#  > Real-time factor: 0.4743046724531649
#  > Text splitted to sentences.
# ['You cows that I see before me how many thousands of gallons of milk have you given during this last year']
#  > Processing time: 2.844254970550537
#  > Real-time factor: 0.42016710057776385
#  > Text splitted to sentences.
# ['Вы коровы которых я вижу передо мной сколько тысяч галлонов молока вы дали за прошлый год']
#  > Processing time: 3.0323596000671387
#  > Real-time factor: 0.38237446919594886
#  > Text splitted to sentences.
# ['And what has happened to that milk which should have been breeding up sturdy calves']
#  > Processing time: 1.9205491542816162
#  > Real-time factor: 0.38464711571637156
#  > Text splitted to sentences.
# ['А что случилось с молоком которое должно было вырастить крепкие телята']
#  > Processing time: 3.3318958282470703
#  > Real-time factor: 0.4024690102816192
#  > Text splitted to sentences.
# ['Every drop of it has gone down the throats of our enemies']
#  > Processing time: 2.440298318862915
#  > Real-time factor: 0.5374837974561218
#  > Text splitted to sentences.
# ['Каждая капля попадает в глотки наших врагов']
#  > Processing time: 2.0636911392211914
#  > Real-time factor: 0.4751920386364586
#  > Text splitted to sentences.
# ['And you hens how many eggs have you laid in this last year and how many of those eggs ever hatched into chickens']
#  > Processing time: 2.5405125617980957
#  > Real-time factor: 0.38385526523714514
#  > Text splitted to sentences.
# ['А вы курицы сколько яиц выложили в прошлом году и сколько яиц когда-либо вылупилось в цыплята']
#  > Processing time: 3.8278517723083496
#  > Real-time factor: 0.3829032607761083
#  > Text splitted to sentences.
# ['The rest have all gone to market to bring in money for Jones and his men']
#  > Processing time: 1.7739989757537842
#  > Real-time factor: 0.3857964870539189
#  > Text splitted to sentences.
# ['Остальные пошли на рынок чтобы принести деньги Джонсу и его людям']
#  > Processing time: 3.3143527507781982
#  > Real-time factor: 0.4862762040526141
#  > Text splitted to sentences.
# ['And you Clover where are those four foals you bore who should have been the support and pleasure of your old age']
#  > Processing time: 3.9538724422454834
#  > Real-time factor: 0.4278032864465382
#  > Text splitted to sentences.
# ['А ты Кловер где те четыре подружки которые тебе понравились кто должен был быть поддержкой и удовольствием твоей старости']
#  > Processing time: 4.021472454071045
#  > Real-time factor: 0.38103071335625016
#  > Text splitted to sentences.
# ['Each was sold at a year old — you will never see one of them again']
#  > Processing time: 1.8107035160064697
#  > Real-time factor: 0.38984155335047904
#  > Text splitted to sentences.
# ['Каждый был продан в год и вы больше никогда не увидите ни одного из них']
#  > Processing time: 2.672269821166992
#  > Real-time factor: 0.43753378249919933
#  > Text splitted to sentences.
# ['In return for your four confinements and all your labour in the fields what have you ever had except your bare rations and a stall']
#  > Processing time: 6.543001174926758
#  > Real-time factor: 0.45300545060014763
#  > Text splitted to sentences.
# ['В обмен на ваши четыре заключения и все ваши работы на полях что у вас когда-либо было кроме голого пайка и кабинки']
#  > Processing time: 3.800255537033081
#  > Real-time factor: 0.3819169519414945
#  > Text splitted to sentences.
# ['“And even the miserable lives we lead are not allowed to reach their natural span']
#  > Processing time: 2.130843162536621
#  > Real-time factor: 0.3839153135535077
#  > Text splitted to sentences.
# ['▪ И даже те жалкие жизни которые мы ведем не могут достичь их естественной продолжительности']
#  > Processing time: 4.669631004333496
#  > Real-time factor: 0.5162723808942719
#  > Text splitted to sentences.
# ['For myself I do not grumble for I am one of the lucky ones']
#  > Processing time: 1.594555377960205
#  > Real-time factor: 0.4050685032721489
#  > Text splitted to sentences.
# ['Я сам себе не ворчу потому что я один из счастливчиков']
#  > Processing time: 1.8443641662597656
#  > Real-time factor: 0.3883520804624506
#  > Text splitted to sentences.
# ['I am twelve years old and have had over four hundred children']
#  > Processing time: 1.9398119449615479
#  > Real-time factor: 0.38404012881053484
#  > Text splitted to sentences.
# ['Мне двенадцать лет и у меня было более четырехсот детей']
#  > Processing time: 1.8873279094696045
#  > Real-time factor: 0.3851582667314969
#  > Text splitted to sentences.
# ['Such is the natural life of a pig']
#  > Processing time: 1.0548241138458252
#  > Real-time factor: 0.40190198559407736
#  > Text splitted to sentences.
# ['Такова естественная жизнь свиней']
#  > Processing time: 1.3300237655639648
#  > Real-time factor: 0.3882522774661807
#  > Text splitted to sentences.
# ['But no animal escapes the cruel knife in the end']
#  > Processing time: 1.786858081817627
#  > Real-time factor: 0.47936807358476097
#  > Text splitted to sentences.
# ['Но ни одно животное не сбежит от жестокого ножа в конце концов']
#  > Processing time: 3.4522154331207275
#  > Real-time factor: 0.5652351661838544
#  > Text splitted to sentences.
# ['You young porkers who are sitting in front of me every one of you will scream your lives out at the block within a year']
#  > Processing time: 2.4048216342926025
#  > Real-time factor: 0.39077288229683915
#  > Text splitted to sentences.
# ['Вы молодые сопляки сидящие передо мной каждый из вас будет кричать о своих жизнях в квартале в течение года']
#  > Processing time: 3.713348865509033
#  > Real-time factor: 0.3867194819980077
#  > Text splitted to sentences.
# ['To that horror we all must come — cows pigs hens sheep everyone']
#  > Processing time: 1.9638645648956299
#  > Real-time factor: 0.3852599079710733
#  > Text splitted to sentences.
# ['К этому ужасу мы все должны прийти: коровы свинья куры овцы все']
#  > Processing time: 4.098012208938599
#  > Real-time factor: 0.44118217916127694
#  > Text splitted to sentences.
# ['Even the horses and the dogs have no better fate']
#  > Processing time: 1.7437078952789307
#  > Real-time factor: 0.5753046308789266
#  > Text splitted to sentences.
# ['Даже у лошадей и собак нет лучшей судьбы']
#  > Processing time: 2.3926639556884766
#  > Real-time factor: 0.38230608857196313
#  > Text splitted to sentences.
# ['You Boxer the very day that those great muscles of yours lose their power Jones will sell you to the knacker who will cut your throat and boil you down for the foxhounds']
#  > Processing time: 4.144315719604492
#  > Real-time factor: 0.37972110239212425
#  > Text splitted to sentences.
# ['Ты Боксер в тот самый день когда твои великие мышцы потеряют свою силу Джонс продаст тебя хулигану который перережет тебе горло и сварит тебя для лисичек']
#  > Processing time: 6.765439748764038
#  > Real-time factor: 0.44345406201024684
#  > Text splitted to sentences.
# ['As for the dogs when they grow old and toothless Jones ties a brick round their necks and drowns them in the nearest pond']
#  > Processing time: 3.2163524627685547
#  > Real-time factor: 0.4134442437974923
#  > Text splitted to sentences.
# ['А собаки когда они стареют и беззубые Джонс связывает кирпич с их шеями и утопает их в ближайшем пруду']
#  > Processing time: 4.119161128997803
#  > Real-time factor: 0.3810645721219102
#  > Text splitted to sentences.
# ['“Is it not crystal clear then comrades that all the evils of this life of ours spring from the tyranny of human beings']
#  > Processing time: 3.2477786540985107
#  > Real-time factor: 0.38264896620325817
#  > Text splitted to sentences.
# ['▪ Разве не ясно товарищи что все злые деяния нашей жизни проистекают из тирании людей']
#  > Processing time: 3.7075998783111572
#  > Real-time factor: 0.5357592620632865
#  > Text splitted to sentences.
# ['Only get rid of Man and the produce of our labour would be our own']
#  > Processing time: 1.7148687839508057
#  > Real-time factor: 0.43563198947137405
#  > Text splitted to sentences.
# ['Только избавься от человека и продукт нашего труда будет нашим']
#  > Processing time: 2.130056858062744
#  > Real-time factor: 0.3798013465542398
#  > Text splitted to sentences.
# ['Almost overnight we could become rich and free']
#  > Processing time: 1.7391772270202637
#  > Real-time factor: 0.3870181843996933
#  > Text splitted to sentences.
# ['Почти за одну ночь мы могли бы стать богатыми и свободными']
#  > Processing time: 2.157322883605957
#  > Real-time factor: 0.38868618106542807
#  > Text splitted to sentences.
# ['What then must we do']
#  > Processing time: 0.8512818813323975
#  > Real-time factor: 0.4027369868558909
#  > Text splitted to sentences.
# ['Что же нам тогда делать']
#  > Processing time: 1.2074615955352783
#  > Real-time factor: 0.3923680762431161
#  > Text splitted to sentences.
# ['Why work night and day body and soul for the overthrow of the human race']
#  > Processing time: 2.394001007080078
#  > Real-time factor: 0.47395958021580703
#  > Text splitted to sentences.
# ['Работайте ночью и днем телом и душой ради свержения человеческой расы']
#  > Processing time: 3.559941291809082
#  > Real-time factor: 0.5001574159215406
#  > Text splitted to sentences.
# ['That is my message to you comrades: Rebellion']
#  > Processing time: 1.7229456901550293
#  > Real-time factor: 0.402105762784911
#  > Text splitted to sentences.
# ['Это моё послание вам товарищи:']
#  > Processing time: 1.2619335651397705
#  > Real-time factor: 0.39660255289811774
#  > Text splitted to sentences.
# ['I do not know when that Rebellion will come it might be in a week or in a hundred years but I know as surely as I see this straw beneath my feet that sooner or later justice will be done']
#  > Processing time: 4.541022062301636
#  > Real-time factor: 0.3808249272567055
#  > Text splitted to sentences.
# ['Я не знаю когда придет это восстание это может быть через неделю или через сто лет но я знаю как я вижу эту соломинку под моими ногами что рано или поздно правосудие восторжествует']
#  > Processing time: 7.501623630523682
#  > Real-time factor: 0.46117567318621805
#  > Text splitted to sentences.
# ['Fix your eyes on that comrades throughout the short remainder of your lives']
#  > Processing time: 2.113567352294922
#  > Real-time factor: 0.38401582167191023
#  > Text splitted to sentences.
# ['Посмотрите на это товарищи на всю короткую оставшуюся жизнь']
#  > Processing time: 2.241192579269409
#  > Real-time factor: 0.3792073079564954
#  > Text splitted to sentences.
# ['And above all pass on this message of mine to those who come after you so that future generations shall carry on the struggle until it is victorious']
#  > Processing time: 3.518209934234619
#  > Real-time factor: 0.38258763241671934
#  > Text splitted to sentences.
# ['И прежде всего передай мое послание тем кто придет после тебя чтобы будущие поколения продолжали борьбу до тех пор пока она не одержит победу']
#  > Processing time: 6.742906093597412
#  > Real-time factor: 0.461650725830341
#  > Text splitted to sentences.
# ['“And remember comrades your resolution must never falter']
#  > Processing time: 2.1739284992218018
#  > Real-time factor: 0.40262669170676596
#  > Text splitted to sentences.
# ['- И помните товарищи ваше решение не должно ослабевать']
#  > Processing time: 1.4741880893707275
#  > Real-time factor: 0.3894221699566866
#  > Text splitted to sentences.
# ['No argument must lead you astray']
#  > Processing time: 1.0811185836791992
#  > Real-time factor: 0.38952066617853504
#  > Text splitted to sentences.
# ['Ни один довод не должен вводить вас в заблуждение']
#  > Processing time: 1.7669413089752197
#  > Real-time factor: 0.384261636646911
#  > Text splitted to sentences.
# ['Never listen when they tell you that Man and the animals have a common interest that the prosperity of the one is the prosperity of the others']
#  > Processing time: 3.5362398624420166
#  > Real-time factor: 0.504229752760259
#  > Text splitted to sentences.
# ['Никогда не слушай когда они говорят тебе что человек и животные имеют общий интерес что процветание одного - это процветание других']
#  > Processing time: 4.959362506866455
#  > Real-time factor: 0.4305815822324282
#  > Text splitted to sentences.
# ['It is all lies']
#  > Processing time: 0.7374434471130371
#  > Real-time factor: 0.41771033725961954
#  > Text splitted to sentences.
# ['Это всё ложь']
#  > Processing time: 0.7189548015594482
#  > Real-time factor: 0.42108354691845074
#  > Text splitted to sentences.
# ['Man serves the interests of no creature except himself']
#  > Processing time: 1.754673719406128
#  > Real-time factor: 0.3864727056986687
#  > Text splitted to sentences.
# ['Человек служит только самому себе']
#  > Processing time: 1.9813268184661865
#  > Real-time factor: 0.3851764736491343
#  > Text splitted to sentences.
# ['And among us animals let there be perfect unity perfect comradeship in the struggle']
#  > Processing time: 3.696014404296875
#  > Real-time factor: 0.44897045843293354
#  > Text splitted to sentences.
# ['А среди нас животные - идеальное единство идеальное товарищество в борьбе']
#  > Processing time: 3.402946949005127
#  > Real-time factor: 0.45227951240213043
#  > Text splitted to sentences.
# ['All men are enemies']
#  > Processing time: 0.8320493698120117
#  > Real-time factor: 0.4239068531505282
#  > Text splitted to sentences.
# ['Все люди - враги']
#  > Processing time: 0.9481935501098633
#  > Real-time factor: 0.40822531591538747
#  > Text splitted to sentences.
# ['All animals are comrades” At this moment there was a tremendous uproar']
#  > Processing time: 2.100478410720825
#  > Real-time factor: 0.3848852293278337
#  > Text splitted to sentences.
# ['Все животные - товарищи']
#  > Processing time: 1.056856632232666
#  > Real-time factor: 0.4117841521898905
#  > Text splitted to sentences.
# ['While Major was speaking four large rats had crept out of their holes and were sitting on their hindquarters listening to him']
#  > Processing time: 3.02569580078125
#  > Real-time factor: 0.3866283750998294
#  > Text splitted to sentences.
# ['В то время как майор говорил четыре больших крысы вылезли из своих дыр и сидели на задней четверти слушая его']
#  > Processing time: 5.343041658401489
#  > Real-time factor: 0.4991106409194437
#  > Text splitted to sentences.
# ['The dogs had suddenly caught sight of them and it was only by a swift dash for their holes that the rats saved their lives']
#  > Processing time: 2.8552069664001465
#  > Real-time factor: 0.3818371761834257
#  > Text splitted to sentences.
# ['Собаки внезапно увидели их и только при быстром дыре крысы спасли их жизни']
#  > Processing time: 3.3445258140563965
#  > Real-time factor: 0.3850927092903727
#  > Text splitted to sentences.
# ['Major raised his trotter for silence']
#  > Processing time: 0.9725346565246582
#  > Real-time factor: 0.3931576191032692
#  > Text splitted to sentences.
# ['Майор поднял свой тротл для тишины']
#  > Processing time: 1.4486560821533203
#  > Real-time factor: 0.3886371740738845
#  > Text splitted to sentences.
# ['“Comrades” he said “here is a point that must be settled']
#  > Processing time: 2.0435969829559326
#  > Real-time factor: 0.5130865534953807
#  > Text splitted to sentences.
# ['▪ Товарищи он сказал что это вопрос который необходимо урегулировать']
#  > Processing time: 2.9494330883026123
#  > Real-time factor: 0.47926983549310664
#  > Text splitted to sentences.
# ['The wild creatures such as rats and rabbits — are they our friends or our enemies']
#  > Processing time: 2.6431210041046143
#  > Real-time factor: 0.3904546182636587
#  > Text splitted to sentences.
# ['Такие дикие существа как крысы и кролики — наши друзья или наши враги']
#  > Processing time: 3.212985038757324
#  > Real-time factor: 0.3832679829081137
#  > Text splitted to sentences.
# ['Let us put it to the vote']
#  > Processing time: 0.7596206665039062
#  > Real-time factor: 0.4192439851925093
#  > Text splitted to sentences.
# ['Давайте проголосуем']
#  > Processing time: 0.775996208190918
#  > Real-time factor: 0.4282818479828229
#  > Text splitted to sentences.
# ['I propose this question to the meeting: Are rats comrades” The vote was taken at once and it was agreed by an overwhelming majority that rats were comrades']
#  > Processing time: 5.035617351531982
#  > Real-time factor: 0.48621244045260376
#  > Text splitted to sentences.
# ['Я предлагаю этот вопрос совещанию: являются ли крысы товарищами Голосование было проведено одновременно и подавляющее большинство согласилось с тем что крысы были товарищами']
#  > Processing time: 5.909863471984863
#  > Real-time factor: 0.38737363126416835
#  > Text splitted to sentences.
# ['There were only four dissentients the three dogs and the cat who was afterwards discovered to have voted on both sides']
#  > Processing time: 2.8313653469085693
#  > Real-time factor: 0.3816112830032638
#  > Text splitted to sentences.
# ['Было только четыре инакомыслящих три собаки и кошка которые впоследствии были обнаружены что проголосовали с обеих сторон']
#  > Processing time: 4.818450927734375
#  > Real-time factor: 0.4721242577165969
#  > Text splitted to sentences.
# ['Major continued: “I have little more to say']
#  > Processing time: 1.6582443714141846
#  > Real-time factor: 0.4504766458417452
#  > Text splitted to sentences.
# ['Майор продолжил: мне нечего сказать']
#  > Processing time: 1.3153963088989258
#  > Real-time factor: 0.3892592952976878
#  > Text splitted to sentences.
# ['I merely repeat remember always your duty of enmity towards Man and all his ways']
#  > Processing time: 2.6679465770721436
#  > Real-time factor: 0.38295634585225996
#  > Text splitted to sentences.
# ['Я лишь повторяю всегда помню свой долг вражды по отношению к человеку и по всем его путям']
#  > Processing time: 3.386068105697632
#  > Real-time factor: 0.37873753008396627
#  > Text splitted to sentences.
# ['Whatever goes upon two legs is an enemy']
#  > Processing time: 1.4209222793579102
#  > Real-time factor: 0.3909380148213456
#  > Text splitted to sentences.
# ['Что бы ни происходило на двух ногах это враг']
#  > Processing time: 2.0702569484710693
#  > Real-time factor: 0.512313316055251
#  > Text splitted to sentences.
# ['Whatever goes upon four legs or has wings is a friend']
#  > Processing time: 2.7942609786987305
#  > Real-time factor: 0.553202257041975
#  > Text splitted to sentences.
# ['Что бы ни было на четырёх ногах или крыльях это друг']
#  > Processing time: 1.752356767654419
#  > Real-time factor: 0.3859623893916807
#  > Text splitted to sentences.
# ['And remember also that in fighting against Man we must not come to resemble him']
#  > Processing time: 2.3885812759399414
#  > Real-time factor: 0.3845069000005527
#  > Text splitted to sentences.
# ['И помните также что в бою с человеком мы не должны приходить чтобы на него походить']
#  > Processing time: 2.978034257888794
#  > Real-time factor: 0.38053810492841855
#  > Text splitted to sentences.
# ['Even when you have conquered him do not adopt his vices']
#  > Processing time: 1.6224448680877686
#  > Real-time factor: 0.38279949218172504
#  > Text splitted to sentences.
# ['Даже если ты одержишь победу над ним не принимай его пороков']
#  > Processing time: 2.105398654937744
#  > Real-time factor: 0.4532889425614871
#  > Text splitted to sentences.
# ['No animal must ever live in a house or sleep in a bed or wear clothes or drink alcohol or smoke tobacco or touch money or engage in trade']
#  > Processing time: 5.043508529663086
#  > Real-time factor: 0.46015128715272696
#  > Text splitted to sentences.
# ['Ни одно животное никогда не должно жить в доме спать в постели носить одежду пить алкоголь курить табак прикасаться к деньгам или заниматься торговлей']
#  > Processing time: 5.6279401779174805
#  > Real-time factor: 0.3775130230076674
#  > Text splitted to sentences.
# ['All the habits of Man are evil']
#  > Processing time: 0.9284327030181885
#  > Real-time factor: 0.4185463915102849
#  > Text splitted to sentences.
# ['Все привычки человека - зло']
#  > Processing time: 1.3281300067901611
#  > Real-time factor: 0.43157961933687594
#  > Text splitted to sentences.
# ['And above all no animal must ever tyrannise over his own kind']
#  > Processing time: 3.132462739944458
#  > Real-time factor: 0.5438988551702099
#  > Text splitted to sentences.
# ['И прежде всего ни одно животное никогда не должно тиранить над своим родом']
#  > Processing time: 3.299941301345825
#  > Real-time factor: 0.41369340543229466
#  > Text splitted to sentences.
# ['Weak or strong clever or simple we are all brothers']
#  > Processing time: 1.8228697776794434
#  > Real-time factor: 0.38382618981886674
#  > Text splitted to sentences.
# ['Слабые или сильные умные или простые мы все братья']
#  > Processing time: 2.068242311477661
#  > Real-time factor: 0.39061209202482555
#  > Text splitted to sentences.
# ['No animal must ever kill any other animal']
#  > Processing time: 1.4168972969055176
#  > Real-time factor: 0.3961577576177554
#  > Text splitted to sentences.
# ['Ни одно животное не должно убивать других животных']
#  > Processing time: 1.8644955158233643
#  > Real-time factor: 0.38506037505530855
#  > Text splitted to sentences.
# ['All animals are equal']
#  > Processing time: 0.9965858459472656
#  > Real-time factor: 0.5077337777989188
#  > Text splitted to sentences.
# ['Все животные равны']
#  > Processing time: 1.0857551097869873
#  > Real-time factor: 0.5403778478422506
#  > Text splitted to sentences.
# ['“And now comrades I will tell you about my dream of last night']
#  > Processing time: 2.1447715759277344
#  > Real-time factor: 0.5753870601665192
#  > Text splitted to sentences.
# ['- А теперь товарищи я расскажу вам о моей мечте о прошлой ночи']
#  > Processing time: 2.6533145904541016
#  > Real-time factor: 0.4239535269529923
#  > Text splitted to sentences.
# ['I cannot describe that dream to you']
#  > Processing time: 1.1703031063079834
#  > Real-time factor: 0.3936597433196704
#  > Text splitted to sentences.
# ['Я не могу описать эту мечту']
#  > Processing time: 0.9999949932098389
#  > Real-time factor: 0.3968091275604115
#  > Text splitted to sentences.
# ['It was a dream of the earth as it will be when Man has vanished']
#  > Processing time: 1.7423763275146484
#  > Real-time factor: 0.3969602209218259
#  > Text splitted to sentences.
# ['Это была мечта о земле как будет когда исчезнет человек']
#  > Processing time: 1.9899249076843262
#  > Real-time factor: 0.38684797057447623
#  > Text splitted to sentences.
# ['But it reminded me of something that I had long forgotten']
#  > Processing time: 1.2931182384490967
# ...
# ['All the other male pigs on the farm were porkers']
#  > Processing time: 1.3240413665771484
#  > Real-time factor: 0.386505932707929
#  > Text splitted to sentences.
# ['Все остальные мужские свиньи на ферме были свиньями']
#  > Processing time: 1.942777156829834
#  > Real-time factor: 0.38462717558628284
#  > Text splitted to sentences.
# ['The best known among them was a small fat pig named Squealer with very round cheeks twinkling eyes nimble movements and a shrill voice']
#  > Processing time: 3.7401256561279297
#  > Real-time factor: 0.3798629722051222
#  > Text splitted to sentences.
# ['Самой известной среди них была маленькая жирная свинья по имени Сквилер с очень круглыми щеками блестящими глазами щекотливыми движениями и скрипящим голосом']
#  > Processing time: 8.078192949295044
#  > Real-time factor: 0.46477517046913674
#  > Text splitted to sentences.
# ['He was a brilliant talker and when he was arguing some difficult point he had a way of skipping from side to side and whisking his tail which was somehow very persuasive']
#  > Processing time: 4.5264763832092285
#  > Real-time factor: 0.3796050791462434
#  > Text splitted to sentences.
# ['Он был блестящим болтуном и когда он спорил о какой-то трудной точке у него был способ проскользнуть из стороны в сторону и стукнуть хвостом что каким-то образом было очень убедительным']
#  > Processing time: 8.40319299697876
#  > Real-time factor: 0.4445717819863086
#  > Text splitted to sentences.
# ['The others said of Squealer that he could turn black into white']
#  > Processing time: 1.7486340999603271
#  > Real-time factor: 0.3891226173111296
#  > Text splitted to sentences.
# ['Другие говорили о Сквилере что он может превратить чёрное в белое']
#  > Processing time: 2.5799362659454346
#  > Real-time factor: 0.3844171982383016
#  > Text splitted to sentences.
# ['These three had elaborated old Major’s teachings into a complete system of thought to which they gave the name of Animalism']
#  > Processing time: 2.972731351852417
#  > Real-time factor: 0.3821281031873531
#  > Text splitted to sentences.
# ['Эти трое развили старые учения майора в полную систему мысли которой они назвали животное']
#  > Processing time: 4.597979784011841
#  > Real-time factor: 0.5358639230309783
#  > Text splitted to sentences.
# ['Several nights a week after Mr Jones was asleep they held secret meetings in the barn and expounded the principles of Animalism to the others']
#  > Processing time: 3.7407610416412354
#  > Real-time factor: 0.389574269667636
#  > Text splitted to sentences.
# ['Несколько ночей в неделю после того как мистер Джонс спал они проводили тайные встречи в сарае и разъясняли другим принципы животного']
#  > Processing time: 4.615246295928955
#  > Real-time factor: 0.38074745893906564
#  > Text splitted to sentences.
# ['At the beginning they met with much stupidity and apathy']
#  > Processing time: 1.7160236835479736
#  > Real-time factor: 0.3868632649909294
#  > Text splitted to sentences.
# ['В начале они встретились с большой глупостью и апатией']
#  > Processing time: 2.0815532207489014
#  > Real-time factor: 0.5035352874047007
#  > Text splitted to sentences.
# ['Some of the animals talked of the duty of loyalty to Mr Jones whom they referred to as “Master” or made elementary remarks such as “Mr']
#  > Processing time: 5.454121112823486
#  > Real-time factor: 0.4574003930268281
#  > Text splitted to sentences.
# ['Некоторые животные говорили об обязанности лояльности мистеру Джонсу которого они назвали Мастером или высказывали такие элементарные замечания как:']
#  > Processing time: 4.565495491027832
#  > Real-time factor: 0.37955139491902823
#  > Text splitted to sentences.
# ['Jones feeds us']
#  > Processing time: 0.8936808109283447
#  > Real-time factor: 0.4028799043377903
#  > Text splitted to sentences.
# ['Джонс кормит нас']
#  > Processing time: 1.119018793106079
#  > Real-time factor: 0.39012086371093224
#  > Text splitted to sentences.
# ['If he were gone we should starve to death” Others asked such questions as “Why should we care what happens after we are dead” or “If this Rebellion is to happen anyway what difference does it make whether we work for it or not” and the pigs had great difficulty in making them see that this was contrary to the spirit of Animalism']
# [!] Warning: The text length exceeds the character limit of 250 for language 'en', this might cause truncated audio.
#  > Processing time: 10.173254013061523
#  > Real-time factor: 0.44728076843995573
#  > Text splitted to sentences.
# ['Если он умер мы должны умереть с голоду Другие задавали такие вопросы как: "Почему нас должно волновать что происходит после смерти" или "Если это восстание произойдет в любом случае какая разница работаем мы на него или нет"']
# [!] Warning: The text length exceeds the character limit of 213 for language 'it', this might cause truncated audio.
#  > Processing time: 8.219735860824585
#  > Real-time factor: 0.42597012308498033
#  > Text splitted to sentences.
# ['The stupidest questions of all were asked by Mollie the white mare']
#  > Processing time: 1.740077257156372
#  > Real-time factor: 0.42093101106172115
#  > Text splitted to sentences.
# ['Самые глупые вопросы были заданы Молли белой кобылой']
#  > Processing time: 1.9051733016967773
#  > Real-time factor: 0.3972714414284871
#  > Text splitted to sentences.
# ['The very first question she asked Snowball was: “Will there still be sugar after the Rebellion” “No” said Snowball firmly']
#  > Processing time: 3.2172186374664307
#  > Real-time factor: 0.38861683186593254
#  > Text splitted to sentences.
# ['Самый первый вопрос который она задала Снежкам был: "Будет ли сахар после Ребеллиона"']
#  > Processing time: 2.537971019744873
#  > Real-time factor: 0.3834712544223115
#  > Text splitted to sentences.
# ['“We have no means of making sugar on this farm']
#  > Processing time: 1.210627555847168
#  > Real-time factor: 0.422058209056888
#  > Text splitted to sentences.
# ['▪ У нас нет средств для производства сахара на этой ферме']
#  > Processing time: 2.4461510181427
#  > Real-time factor: 0.5319712595672887
#  > Text splitted to sentences.
# ['Besides you do not need sugar']
#  > Processing time: 1.7954132556915283
#  > Real-time factor: 0.5642654259976939
#  > Text splitted to sentences.
# ['Кроме того тебе не нужен сахар']
#  > Processing time: 1.1381254196166992
#  > Real-time factor: 0.40331167238602816
#  > Text splitted to sentences.
# ['You will have all the oats and hay you want” “And shall I still be allowed to wear ribbons in my mane” asked Mollie']
#  > Processing time: 2.9184205532073975
#  > Real-time factor: 0.3779671388862837
#  > Text splitted to sentences.
# ['У тебя будет столько овсянка и сена сколько ты хочешь - И мне все еще позволено носить ленточки в моей гриве - Спросила Молли']
#  > Processing time: 5.747771501541138
#  > Real-time factor: 0.37532090028720116
#  > Text splitted to sentences.
# ['“Comrade” said Snowball “those ribbons that you are so devoted to are the badge of slavery']
#  > Processing time: 4.023400545120239
#  > Real-time factor: 0.534742875517777
#  > Text splitted to sentences.
# ['▪ Товарищ говорит Снежок те ленты которым вы так преданы являются знамением рабства']
#  > Processing time: 4.398871183395386
#  > Real-time factor: 0.4145090153584114
#  > Text splitted to sentences.
# ['Can you not understand that liberty is worth more than ribbons” Mollie agreed but she did not sound very convinced']
#  > Processing time: 3.137505531311035
#  > Real-time factor: 0.38112602999894407
#  > Text splitted to sentences.
# ['Молли согласилась но она не была уверена']
#  > Processing time: 1.737790822982788
#  > Real-time factor: 0.3827541917729191
#  > Text splitted to sentences.
# ['The pigs had an even harder struggle to counteract the lies put about by Moses the tame raven']
#  > Processing time: 2.6999568939208984
#  > Real-time factor: 0.42744148126763215
#  > Text splitted to sentences.
# ['Свиньи боролись еще сильнее чтобы противостоять лжи Моисея ручной ворона']
#  > Processing time: 3.918011426925659
#  > Real-time factor: 0.48762842027742476
#  > Text splitted to sentences.
# ['Moses who was Mr Jones’s especial pet was a spy and a tale-bearer but he was also a clever talker']
#  > Processing time: 2.853487730026245
#  > Real-time factor: 0.3769254076432875
#  > Text splitted to sentences.
# ['Моисей который был мистером Джонсонсом был шпионом и носителем рассказов но он также был умным болтуном']
#  > Processing time: 4.172801971435547
#  > Real-time factor: 0.37397689516060434
#  > Text splitted to sentences.
# ['He claimed to know of the existence of a mysterious country called Sugarcandy Mountain to which all animals went when they died']
#  > Processing time: 3.6142373085021973
#  > Real-time factor: 0.44723631056654306
#  > Text splitted to sentences.
# ['Он утверждал что знает о существовании загадочной страны под названием Сахарная Гора в которую все животные ушли когда они умерли']
#  > Processing time: 6.344425201416016
#  > Real-time factor: 0.4501112473977579
#  > Text splitted to sentences.
# ['It was situated somewhere up in the sky a little distance beyond the clouds Moses said']
#  > Processing time: 2.563788652420044
#  > Real-time factor: 0.3907998270784618
#  > Text splitted to sentences.
# ['Моисей сказал что он был расположен где-то на небе на расстоянии от облаков']
#  > Processing time: 2.2866413593292236
#  > Real-time factor: 0.38689719132296946
#  > Text splitted to sentences.
# ['In Sugarcandy Mountain it was Sunday seven days a week clover was in season all the year round and lump sugar and linseed cake grew on the hedges']
#  > Processing time: 5.689359188079834
#  > Real-time factor: 0.4919776702687157
#  > Text splitted to sentences.
# ['На горе Шугарканди было воскресенье семь дней в неделю клевер был в сезоне весь год а на хеджированиях выращивались кусок сахара и льняного торта']
#  > Processing time: 5.632118225097656
#  > Real-time factor: 0.38316448284359517
#  > Text splitted to sentences.
# ['The animals hated Moses because he told tales and did no work but some of them believed in Sugarcandy Mountain and the pigs had to argue very hard to persuade them that there was no such place']
#  > Processing time: 5.259279727935791
#  > Real-time factor: 0.3871558610683998
#  > Text splitted to sentences.
# ['Животные ненавидели Моисея потому что он рассказывал сказки и не делал никакой работы но некоторые из них верили в Сладкую Гору и свиньям пришлось очень сильно спорить чтобы убедить их что такого места нет']
#  > Processing time: 8.227274656295776
#  > Real-time factor: 0.4341980195958954
#  > Text splitted to sentences.
# ['Their most faithful disciples were the two cart-horses Boxer and Clover']
#  > Processing time: 1.6056196689605713
#  > Real-time factor: 0.3973324845189958
#  > Text splitted to sentences.
# ['Их самыми верными учениками были две лошади Боксер и Кловер']
#  > Processing time: 2.3682186603546143
#  > Real-time factor: 0.3848250608773968
#  > Text splitted to sentences.
# ['These two had great difficulty in thinking anything out for themselves but having once accepted the pigs as their teachers they absorbed everything that they were told and passed it on to the other animals by simple arguments']
#  > Processing time: 6.607892751693726
#  > Real-time factor: 0.4918977042309683
#  > Text splitted to sentences.
# ['Этим двум было очень трудно думать о чем - то самостоятельно но однажды приняв свиней в качестве учителей они поглотили все что им было сказано и передали это другим животным простыми аргументами']
#  > Processing time: 7.1382670402526855
#  > Real-time factor: 0.37465911051712814
#  > Text splitted to sentences.
# ['They were unfailing in their attendance at the secret meetings in the barn and led the singing of ‘Beasts of England’ with which the meetings always ended']
#  > Processing time: 4.7429039478302
#  > Real-time factor: 0.45794959035265853
#  > Text splitted to sentences.
# ['Они постоянно присутствовали на тайных встречах в амбаре и возглавляли пение «Зверей Англии» с которым встречи всегда заканчивались']
#  > Processing time: 5.65625262260437
#  > Real-time factor: 0.4192450462822916
#  > Text splitted to sentences.
# ['Now as it turned out the Rebellion was achieved much earlier and more easily than anyone had expected']
#  > Processing time: 2.732889175415039
#  > Real-time factor: 0.3922781892374597
#  > Text splitted to sentences.
# ['Теперь как оказалось восстание было достигнуто гораздо раньше и легче чем кто-либо ожидал']
#  > Processing time: 3.6613759994506836
#  > Real-time factor: 0.3917268689731367
#  > Text splitted to sentences.
# ['In past years Mr Jones although a hard master had been a capable farmer but of late he had fallen on evil days']
#  > Processing time: 4.554542541503906
#  > Real-time factor: 0.49279492345215287
#  > Text splitted to sentences.
# ['В последние годы мистер Джонс хоть и был крепким мастером был способным фермером но в последнее время он попал в плохие дни']
#  > Processing time: 5.0033721923828125
#  > Real-time factor: 0.3780095555412293
#  > Text splitted to sentences.
# ['He had become much disheartened after losing money in a lawsuit and had taken to drinking more than was good for him']
#  > Processing time: 2.8996567726135254
#  > Real-time factor: 0.38302400937007713
#  > Text splitted to sentences.
# ['Он сильно расстроился потеряв деньги в судебном процессе и стал пить больше чем хорошо для него']
#  > Processing time: 4.348924398422241
#  > Real-time factor: 0.509596244926082
#  > Text splitted to sentences.
# ['For whole days at a time he would lounge in his Windsor chair in the kitchen reading the newspapers drinking and occasionally feeding Moses on crusts of bread soaked in beer']
#  > Processing time: 5.366928577423096
#  > Real-time factor: 0.3877889396403924
#  > Text splitted to sentences.
# ['Целые дни он гулял в своем кресле в Виндзоре на кухне читая газеты пья и время от времени кормя Моисея корками хлеба пропитанного пивом']
#  > Processing time: 5.863773584365845
#  > Real-time factor: 0.39610866971982645
#  > Text splitted to sentences.
# ['His men were idle and dishonest the fields were full of weeds the buildings wanted roofing the hedges were neglected and the animals were underfed']
#  > Processing time: 4.7787275314331055
#  > Real-time factor: 0.49290351614821115
#  > Text splitted to sentences.
# ['Его люди были бездельниками и нечестными поля были полны сорняков здания требовали крыши изгороди были оставлены без внимания а животные были недоедания']
#  > Processing time: 5.898756504058838
#  > Real-time factor: 0.38027898241830405
#  > Text splitted to sentences.
# ['June came and the hay was almost ready for cutting']
#  > Processing time: 1.6693034172058105
#  > Real-time factor: 0.3895865828682062
#  > Text splitted to sentences.
# ['Пришла Джун и сено почти готово для резки']
#  > Processing time: 2.049795627593994
#  > Real-time factor: 0.4621093733482698
#  > Text splitted to sentences.
# ['On Midsummer’s Eve which was a Saturday Mr Jones went into Willingdon and got so drunk at the Red Lion that he did not come back till midday on Sunday']
#  > Processing time: 4.861028671264648
#  > Real-time factor: 0.46261343398843957
#  > Text splitted to sentences.
# ['В середине лета в субботу мистер Джонс пошёл в Уиллингдон и напился в "Красном льве" так что вернулся в воскресенье только в полдень']
#  > Processing time: 4.712739944458008
#  > Real-time factor: 0.37757948584129947
#  > Text splitted to sentences.
# ['The men had milked the cows in the early morning and then had gone out rabbiting without bothering to feed the animals']
#  > Processing time: 2.738393783569336
#  > Real-time factor: 0.38726002390779796
#  > Text splitted to sentences.
# ['Ранним утром мужчины доили коров а затем вышли на кролики не потрудившись накормить животных']
#  > Processing time: 4.429462909698486
#  > Real-time factor: 0.5380655418623382
#  > Text splitted to sentences.
# ['When Mr Jones got back he immediately went to sleep on the drawing-room sofa with the News of the World over his face so that when evening came the animals were still unfed']
#  > Processing time: 4.689120292663574
#  > Real-time factor: 0.3982862190032042
#  > Text splitted to sentences.
# ['Когда мистер Джонс вернулся он сразу же пошёл спать на диване в гостиной с "Новостями мира" на лице так что когда пришел вечер звери все еще не питались']
